# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_24_Pandas Inspection.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
import pandas as pd

df = pd.read_csv('/content/data_jobs.csv', on_bad_lines='skip')

df
# Out:
# <ipython-input-4-179e27bdc483>:3: DtypeWarning: Columns (5,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/data_jobs.csv', on_bad_lines='skip')
#                   job_title_short  \
# 0            Senior Data Engineer
# 1                    Data Analyst
# 2                   Data Engineer
# 3                   Data Engineer
# 4                   Data Engineer
# ...                           ...
# 398079           Business Analyst
# 398080          Software Engineer
# 398081               Data Analyst
# 398082  Machine Learning Engineer
# 398083             Data Scientist
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 398079              International Business Analytics Lead
# 398080                                Performance Analyst
# 398081                                       Data Analyst
# 398082            ML/DL Engineer (Recommendation systems)
# 398083                                                Sta
#
#                         job_location                    job_via  \
# 0                      Watertown, CT            via Work Nearby
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 2                    Berlin, Germany               via LinkedIn
# 3                    San Antonio, TX          via Diversity.com
# 4                     Washington, DC         via Clearance Jobs
# ...                              ...                        ...
# 398079        Amsterdam, Netherlands  via Vacatures Trabajo.org
# 398080               Larnaca, Cyprus        via LinkedIn Cyprus
# 398081     Unterschleißheim, Germany               via LinkedIn
# 398082                         India               via LinkedIn
# 398083                           NaN                        NaN
#
#        job_schedule_type job_work_from_home       search_location  \
# 0              Full-time              False  Texas, United States
# 1              Full-time              False                Mexico
# 2              Full-time              False               Germany
# 3              Full-time              False  Texas, United States
# 4              Full-time              False                 Sudan
# ...                  ...                ...                   ...
# 398079         Full-time              False           Netherlands
# 398080         Full-time              False                Cyprus
# 398081         Full-time              False               Germany
# 398082         Full-time              False                 India
# 398083               NaN                NaN                   NaN
#
#             job_posted_date job_no_degree_mention job_health_insurance  \
# 0       2023-06-16 13:44:15                 False                False
# 1       2023-01-14 13:18:07                 False                False
# 2       2023-10-10 13:14:55                 False                False
# 3       2023-07-04 13:01:41                  True                False
# 4       2023-08-07 14:29:36                 False                False
# ...                     ...                   ...                  ...
# 398079  2023-04-09 18:54:24                 False                False
# 398080  2023-11-06 19:21:48                 False                False
# 398081  2023-03-01 18:24:10                 False                False
# 398082  2023-09-07 18:11:04                 False                False
# 398083                  NaN                   NaN                  NaN
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States         NaN              NaN              NaN
# 1              Mexico         NaN              NaN              NaN
# 2             Germany         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4               Sudan         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 398079    Netherlands         NaN              NaN              NaN
# 398080         Cyprus         NaN              NaN              NaN
# 398081        Germany         NaN              NaN              NaN
# 398082          India         NaN              NaN              NaN
# 398083            NaN         NaN              NaN              NaN
#
#                                company_name  \
# 0                      Boehringer Ingelheim
# 1                Hewlett Packard Enterprise
# 2                  ALPHA Augmented Services
# 3              Southwest Research Institute
# 4                           Kristina Daniel
# ...                                     ...
# 398079               Rhythm Pharmaceuticals
# 398080                           HF Markets
# 398081  MZV Moderner Zeitschriften Vertrieb
# 398082                  Akaike Technologies
# 398083                                  NaN
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 398079       ['snowflake', 'powerpoint', 'word', 'excel']
# 398080                                          ['excel']
# 398081                                       ['power bi']
# 398082  ['python', 'aws', 'databricks', 'tensorflow', ...
# 398083                                                NaN
#
#                                           job_type_skills
# 0                                                     NaN
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 398079  {'analyst_tools': ['powerpoint', 'word', 'exce...
# 398080                       {'analyst_tools': ['excel']}
# 398081                    {'analyst_tools': ['power bi']}
# 398082  {'cloud': ['aws', 'databricks'], 'libraries': ...
# 398083                                                NaN
#
# [398084 rows x 17 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Access Third Row (1.24.1)

# %%
df.iloc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                            NaN
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                      ALPHA Augmented Services
# job_skills               ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# job_type_skills          {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# Name: 2, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Unique Job Countries (1.24.2)

# %%
df['job_country'].unique()
# Out:
# array(['United States', 'Mexico', 'Germany', 'Sudan', 'Romania',
#        'Denmark', 'Switzerland', 'France', 'Brazil', 'United Kingdom',
#        'India', 'Poland', 'Belgium', 'Russia', 'Serbia', 'Singapore',
#        'Costa Rica', 'Ireland', 'Italy', 'Malaysia', 'Canada', 'Uruguay',
#        'Namibia', 'Estonia', 'Israel', 'Hungary', 'Austria',
#        'Philippines', 'Egypt', 'Australia', 'Chile', 'Spain',
#        'Netherlands', 'South Africa', 'Colombia', 'Hong Kong', 'Kuwait',
#        'Finland', 'Luxembourg', 'China', 'Puerto Rico', 'Sweden',
#        'Saudi Arabia', 'Argentina', 'Turkey', 'Panama', 'Nigeria',
#        'New Zealand', 'Ukraine', 'Jordan', 'United Arab Emirates',
#        'Armenia', 'Pakistan', 'Lesotho', 'Mauritius', 'Portugal',
#        'Bahrain', 'Taiwan', "Côte d'Ivoire", 'U.S. Virgin Islands',
#        'Réunion', 'Kazakhstan', 'Lithuania', 'Moldova', 'Belarus',
#        'Cyprus', 'Bulgaria', 'Honduras', 'Czechia', 'Peru', 'South Korea',
#        'Malta', 'Indonesia', 'Tunisia', 'Latvia', 'Slovakia', 'Lebanon',
#        'Japan', 'Sri Lanka', 'Slovenia', 'Bangladesh', 'Greece',
#        'Ecuador', 'Oman', 'Kenya', 'Guyana', 'Vietnam', 'Norway',
#        'Senegal', 'El Salvador', 'Iceland', 'Thailand', 'Ghana',
#        'Croatia', 'Myanmar', 'Nepal', 'Morocco', 'Guadeloupe', 'Iraq',
#        'Palestine', 'Guinea', 'Albania', 'Guatemala', 'Qatar', 'Uganda',
#        'Bolivia', nan, 'Dominican Republic', 'Ethiopia', 'Haiti',
#        'Uzbekistan', 'Bahamas', 'Liberia', 'Montenegro', 'Cayman Islands',
#        'Mongolia', 'Macedonia (FYROM)', 'Azerbaijan', 'Burkina Faso',
#        'Guam', 'Trinidad and Tobago', 'Benin', 'Kyrgyzstan',
#        'Bosnia and Herzegovina', 'Zambia', 'Cameroon', 'Venezuela',
#        'Barbados', 'Togo', 'Rwanda', 'Cambodia', 'Algeria', 'Afghanistan',
#        'Congo, Democratic Republic of the', 'Zimbabwe', 'Jamaica',
#        'Suriname', 'Mozambique', 'Yemen', 'Tanzania', 'Madagascar',
#        'Mali', 'Paraguay', 'Brunei', 'Malawi', 'Nicaragua', 'Libya',
#        'Tajikistan', 'Mauritania', 'Botswana', 'Fiji',
#        'Northern Mariana Islands', 'Angola', 'Somalia',
#        'Papua New Guinea', 'Gambia', 'Djibouti', 'Laos', 'Curaçao',
#        'Maldives'], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Filter by Job Schedule Type and Display (1.24.3)

# %%
filtered_df = df[df['job_schedule_type'] == 'Full-time']
filtered_df.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#   job_work_from_home       search_location      job_posted_date  \
# 0              False  Texas, United States  2023-06-16 13:44:15
# 1              False                Mexico  2023-01-14 13:18:07
# 2              False               Germany  2023-10-10 13:14:55
#
#   job_no_degree_mention job_health_insurance    job_country salary_rate  \
# 0                 False                False  United States         NaN
# 1                 False                False         Mexico         NaN
# 2                 False                False        Germany         NaN
#
#    salary_year_avg  salary_hour_avg                company_name  \
# 0              NaN              NaN        Boehringer Ingelheim
# 1              NaN              NaN  Hewlett Packard Enterprise
# 2              NaN              NaN    ALPHA Augmented Services
#
#                                           job_skills  \
# 0                                                NaN
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
#
#                                      job_type_skills
# 0                                                NaN
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Check Missing Values (1.24.4)

# %%
not_na_values = df[df['job_skills'].notna()]
not_na_values
# Out:
#                   job_title_short  \
# 1                    Data Analyst
# 2                   Data Engineer
# 3                   Data Engineer
# 4                   Data Engineer
# 5                   Data Engineer
# ...                           ...
# 398078              Data Engineer
# 398079           Business Analyst
# 398080          Software Engineer
# 398081               Data Analyst
# 398082  Machine Learning Engineer
#
#                                                 job_title  \
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# 5                                       GCP Data Engineer
# ...                                                   ...
# 398078                                      Data Engineer
# 398079              International Business Analytics Lead
# 398080                                Performance Analyst
# 398081                                       Data Analyst
# 398082            ML/DL Engineer (Recommendation systems)
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 2                    Berlin, Germany               via LinkedIn
# 3                    San Antonio, TX          via Diversity.com
# 4                     Washington, DC         via Clearance Jobs
# 5                           Anywhere           via ZipRecruiter
# ...                              ...                        ...
# 398078           Toronto, ON, Canada               via LinkedIn
# 398079        Amsterdam, Netherlands  via Vacatures Trabajo.org
# 398080               Larnaca, Cyprus        via LinkedIn Cyprus
# 398081     Unterschleißheim, Germany               via LinkedIn
# 398082                         India               via LinkedIn
#
#                job_schedule_type job_work_from_home       search_location  \
# 1                      Full-time              False                Mexico
# 2                      Full-time              False               Germany
# 3                      Full-time              False  Texas, United States
# 4                      Full-time              False                 Sudan
# 5       Contractor and Temp work               True               Georgia
# ...                          ...                ...                   ...
# 398078                 Full-time              False                Canada
# 398079                 Full-time              False           Netherlands
# 398080                 Full-time              False                Cyprus
# 398081                 Full-time              False               Germany
# 398082                 Full-time              False                 India
#
#             job_posted_date job_no_degree_mention job_health_insurance  \
# 1       2023-01-14 13:18:07                 False                False
# 2       2023-10-10 13:14:55                 False                False
# 3       2023-07-04 13:01:41                  True                False
# 4       2023-08-07 14:29:36                 False                False
# 5       2023-11-07 14:01:59                 False                False
# ...                     ...                   ...                  ...
# 398078  2023-12-12 18:28:54                  True                False
# 398079  2023-04-09 18:54:24                 False                False
# 398080  2023-11-06 19:21:48                 False                False
# 398081  2023-03-01 18:24:10                 False                False
# 398082  2023-09-07 18:11:04                 False                False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 1              Mexico         NaN              NaN              NaN
# 2             Germany         NaN              NaN              NaN
# 3       United States         NaN              NaN              NaN
# 4               Sudan         NaN              NaN              NaN
# 5       United States         NaN              NaN              NaN
# ...               ...         ...              ...              ...
# 398078         Canada         NaN              NaN              NaN
# 398079    Netherlands         NaN              NaN              NaN
# 398080         Cyprus         NaN              NaN              NaN
# 398081        Germany         NaN              NaN              NaN
# 398082          India         NaN              NaN              NaN
#
#                                company_name  \
# 1                Hewlett Packard Enterprise
# 2                  ALPHA Augmented Services
# 3              Southwest Research Institute
# 4                           Kristina Daniel
# 5                           smart folks inc
# ...                                     ...
# 398078                     Elevate Security
# 398079               Rhythm Pharmaceuticals
# 398080                           HF Markets
# 398081  MZV Moderner Zeitschriften Vertrieb
# 398082                  Akaike Technologies
#
#                                                job_skills  \
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                                ['python', 'sql', 'gcp']
# ...                                                   ...
# 398078  ['python', 'aws', 'spark', 'airflow', 'kuberne...
# 398079       ['snowflake', 'powerpoint', 'word', 'excel']
# 398080                                          ['excel']
# 398081                                       ['power bi']
# 398082  ['python', 'aws', 'databricks', 'tensorflow', ...
#
#                                           job_type_skills
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5       {'cloud': ['gcp'], 'programming': ['python', '...
# ...                                                   ...
# 398078  {'cloud': ['aws'], 'libraries': ['spark', 'air...
# 398079  {'analyst_tools': ['powerpoint', 'word', 'exce...
# 398080                       {'analyst_tools': ['excel']}
# 398081                    {'analyst_tools': ['power bi']}
# 398082  {'cloud': ['aws', 'databricks'], 'libraries': ...
#
# [335545 rows x 17 columns]

# %% [markdown]
# ---
