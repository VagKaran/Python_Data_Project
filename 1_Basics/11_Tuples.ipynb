# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_11_Tuples.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Access Job Role (1.11.1)

# %%
# Code Needed
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
print(job_roles[1])
# Out:
# Data Analyst

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Add Job Role to Tuple (1.11.2)

# %%
# Code Needed
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
job_roles_new = job_roles + ('AI Specialist',)
print(job_roles_new)
# Out:
# ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'AI Specialist')

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Remove Job Role from Tuple (1.11.3)

# %%
# Code Needed
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')
job_roles_remove = list(job_roles)
job_roles_remove.remove('Data Analyst')
job_roles_new = tuple(job_roles_remove)
print(job_roles_new)
# Out:
# ('Data Scientist', 'Machine Learning Engineer')

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Unpack Job Postings Tuple (1.11.4)

# %%
# Code Needed
job_postings = (120, 80, 50)
data_scientist_postings, data_analyst_postings,ml_engineer_postings = job_postings
print('data_scientist_postings:', data_scientist_postings)
print('data_analyst_postings:',data_analyst_postings)
print('ml_engineer_postings:',ml_engineer_postings)
# Out:
# data_scientist_postings: 120
# data_analyst_postings: 80
# ml_engineer_postings: 50

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Extract Nested Value from Tuple (1.11.5)

# %%
# Code Needed
job_details = (('Data Scientist', 120), ('Data Analyst', 80), ('Machine Learning Engineer', 50))
postings = job_details[2][1]
print(postings)
# Out:
# 50

# %% [markdown]
# ---
