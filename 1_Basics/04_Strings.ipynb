# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_04_Strings.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Convert to Uppercase (1.4.1)

# %%
# Code Needed
job_title = 'data scientist'
job_title_upper = job_title.upper()
print(job_title_upper)
# Out:
# DATA SCIENTIST

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Replace Substring (1.4.2)

# %%
# Code Needed
job_title = 'Data Analyst'
job_title_updated = job_title.replace('Analyst', 'Engineer')
print(job_title_updated)
# Out:
# Data Engineer

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Concatenate Strings (1.4.3)

# %%
# Code Needed
seniority_level = 'Senior'
job_title = 'Data Analyst'
full_job_title= 'Senior' + ' ' + 'Data Analyst'
print(full_job_title)
# Out:
# Senior Data Analyst

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Check String Length (1.4.4)

# %%
# Code Needed
job_title = 'Data Scientist'
job_title_lenght = len(job_title)
print(job_title_lenght)
# Out:
# 14

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Convert to lowercase (1.4.5)

# %%
# Code Needed
job_title = 'DATA ENGINEER'
job_title_lower = job_title.lower()
print(job_title_lower)
# Out:
# data engineer

# %% [markdown]
# ---
