# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/Blank Python Notebook.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Blank Python Notebook
# A blank Colab notebook to work practice problems from my ["Python for Data Analytics Course"](https://www.youtube.com/watch?v=wUSDVGivd-8).

# %%
import pandas as pd

df = pd.read_csv("hf://datasets/lukebarousse/data_jobs/data_jobs.csv")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
df['job_country'].isin(['Greece']).any()
# Out:
# np.True_

# %%
 gr_jobs = df[df['job_country'] == 'Greece']
 gr_jobs
# Out:
#           job_title_short                                          job_title  \
# 1003         Data Analyst                      Data Quality Analyst – Greece
# 1050        Data Engineer  Sr. Manager, Regulatory Quality Assurance Data...
# 1235         Data Analyst                                       Data Analyst
# 1281        Data Engineer                        (Mid/ Senior) Data Engineer
# 1831       Data Scientist                     Senior Associate, Data Science
# ...                   ...                                                ...
# 776435       Data Analyst                                     Data Architect
# 778433   Business Analyst                                      Sales Analyst
# 780458      Data Engineer                          Azure Cloud Data Engineer
# 780973      Data Engineer                                      Data Engineer
# 783226  Software Engineer         Senior Software Engineer - Query Languages
#
#                 job_location           job_via job_schedule_type  \
# 1003                  Greece      via LinkedIn         Full-time
# 1050    Thessaloniki, Greece      via LinkedIn         Full-time
# 1235    Thessaloniki, Greece      via LinkedIn         Full-time
# 1281          Athens, Greece      via LinkedIn         Full-time
# 1831    Thessaloniki, Greece      via LinkedIn         Full-time
# ...                      ...               ...               ...
# 776435        Athens, Greece  via Startup Jobs         Full-time
# 778433                Greece         via BeBee         Full-time
# 780458        Athens, Greece        via Indeed         Full-time
# 780973        Athens, Greece        via Jooble         Full-time
# 783226              Anywhere      via LinkedIn         Full-time
#
#         job_work_from_home search_location      job_posted_date  \
# 1003                 False          Greece  2023-02-24 13:56:02
# 1050                 False          Greece  2023-02-24 13:56:18
# 1235                 False          Greece  2023-11-24 13:29:51
# 1281                 False          Greece  2023-03-21 13:40:13
# 1831                 False          Greece  2023-02-24 13:56:06
# ...                    ...             ...                  ...
# 776435               False          Greece  2023-01-15 01:26:12
# 778433               False          Greece  2023-08-15 05:17:56
# 780458               False          Greece  2023-01-05 05:56:33
# 780973               False          Greece  2023-01-05 06:56:33
# 783226                True          Greece  2023-01-10 06:34:00
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 1003                    False                 False      Greece         NaN
# 1050                    False                 False      Greece         NaN
# 1235                    False                 False      Greece         NaN
# 1281                    False                 False      Greece         NaN
# 1831                    False                 False      Greece         NaN
# ...                       ...                   ...         ...         ...
# 776435                  False                 False      Greece         NaN
# 778433                  False                 False      Greece         NaN
# 780458                  False                 False      Greece         NaN
# 780973                  False                 False      Greece         NaN
# 783226                  False                 False      Greece         NaN
#
#         salary_year_avg  salary_hour_avg          company_name  \
# 1003                NaN              NaN       Poudouleveis.gr
# 1050                NaN              NaN       Poudouleveis.gr
# 1235                NaN              NaN        Campeón Gaming
# 1281                NaN              NaN            Dialectica
# 1831                NaN              NaN       Poudouleveis.gr
# ...                 ...              ...                   ...
# 776435              NaN              NaN           Uni Systems
# 778433              NaN              NaN       Randstad Hellas
# 780458              NaN              NaN  Netcompany-Intrasoft
# 780973              NaN              NaN              improvIT
# 783226              NaN              NaN               Elastic
#
#                                                job_skills  \
# 1003                                              ['sql']
# 1050                             ['oracle', 'sharepoint']
# 1235        ['sql', 'python', 'r', 'tableau', 'power bi']
# 1281                     ['sql', 'python', 'aws', 'flow']
# 1831                             ['r', 'python', 'excel']
# ...                                                   ...
# 776435                                        ['express']
# 778433                                          ['excel']
# 780458  ['sql', 'c#', 'powershell', 'python', 'azure',...
# 780973  ['sql', 'python', 'java', 'c#', 'nosql', 'mong...
# 783226  ['java', 'mongodb', 'mongodb', 'elasticsearch'...
#
#                                           job_type_skills
# 1003                             {'programming': ['sql']}
# 1050    {'analyst_tools': ['sharepoint'], 'cloud': ['o...
# 1235    {'analyst_tools': ['tableau', 'power bi'], 'pr...
# 1281    {'cloud': ['aws'], 'other': ['flow'], 'program...
# 1831    {'analyst_tools': ['excel'], 'programming': ['...
# ...                                                   ...
# 776435                     {'webframeworks': ['express']}
# 778433                       {'analyst_tools': ['excel']}
# 780458  {'analyst_tools': ['power bi', 'tableau', 'dax...
# 780973  {'analyst_tools': ['sap', 'ssis', 'tableau', '...
# 783226  {'databases': ['mongodb', 'elasticsearch', 'po...
#
# [2055 rows x 17 columns]

# %%
gr_jobs = gr_jobs[gr_jobs['salary_year_avg'].notna()]

gr_jobs
# Out:
#                   job_title_short  \
# 11741              Data Scientist
# 15254       Senior Data Scientist
# 29149           Software Engineer
# 58901                Data Analyst
# 80165              Data Scientist
# ...                           ...
# 749852               Data Analyst
# 752893              Data Engineer
# 765797  Machine Learning Engineer
# 767505  Machine Learning Engineer
# 771592              Data Engineer
#
#                                                 job_title        job_location  \
# 11741                               Junior Data Scientist      Athens, Greece
# 15254                            Senior Research Engineer  Nea Smyrni, Greece
# 29149   Senior Software Engineer (On Image Processing ...     Paiania, Greece
# 58901                      Business Intelligence Engineer      Athens, Greece
# 80165                                 Lead Data Scientist      Athens, Greece
# ...                                                   ...                 ...
# 749852                                     Data Architect      Athens, Greece
# 752893                                  Big Data Engineer  Nea Smyrni, Greece
# 765797  Machine Learning Engineer (Electricity Trading...      Athens, Greece
# 767505                                        AI Engineer      Athens, Greece
# 771592                                      Data Engineer     Marousi, Greece
#
#                 job_via job_schedule_type  job_work_from_home search_location  \
# 11741   via Ai-Jobs.net         Full-time               False          Greece
# 15254   via Ai-Jobs.net         Full-time               False          Greece
# 29149   via Ai-Jobs.net         Full-time               False          Greece
# 58901   via Ai-Jobs.net         Full-time               False          Greece
# 80165   via Ai-Jobs.net         Full-time               False          Greece
# ...                 ...               ...                 ...             ...
# 749852  via Ai-Jobs.net         Full-time               False          Greece
# 752893  via Ai-Jobs.net         Full-time               False          Greece
# 765797  via Ai-Jobs.net         Full-time               False          Greece
# 767505  via Ai-Jobs.net         Full-time               False          Greece
# 771592  via Ai-Jobs.net         Full-time               False          Greece
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 11741   2023-01-16 14:07:22                  False                 False
# 15254   2023-03-06 14:28:55                  False                 False
# 29149   2023-06-29 14:02:41                  False                 False
# 58901   2023-04-10 06:27:35                  False                 False
# 80165   2023-02-10 00:59:07                  False                 False
# ...                     ...                    ...                   ...
# 749852  2023-01-16 21:07:22                  False                 False
# 752893  2023-01-19 21:14:22                  False                 False
# 765797  2023-04-05 01:50:57                  False                 False
# 767505  2023-07-22 01:43:30                  False                 False
# 771592  2023-01-21 02:19:06                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 11741       Greece        year          64821.5              NaN
# 15254       Greece        year         200000.0              NaN
# 29149       Greece        year          89100.0              NaN
# 58901       Greece        year          89100.0              NaN
# 80165       Greece        year          51068.0              NaN
# ...            ...         ...              ...              ...
# 749852      Greece        year         163782.0              NaN
# 752893      Greece        year          45000.0              NaN
# 765797      Greece        year         104668.0              NaN
# 767505      Greece        year          89100.0              NaN
# 771592      Greece        year          96773.0              NaN
#
#                 company_name  \
# 11741             PeopleCert
# 15254    WINGS-ICT-SOLUTIONS
# 29149               INTRALOT
# 58901          Kaizen Gaming
# 80165             iTechScope
# ...                      ...
# 749852           Uni Systems
# 752893           INCELLIGENT
# 765797  ManpowerGroup Greece
# 767505                Satori
# 771592       Out There Media
#
#                                                job_skills  \
# 11741   ['python', 'azure', 'databricks', 'spark', 'po...
# 15254                     ['word', 'excel', 'powerpoint']
# 29149                       ['go', 'tensorflow', 'linux']
# 58901   ['python', 'sql', 'databricks', 'spark', 'tabl...
# 80165   ['python', 'spark', 'kafka', 'kubernetes', 'do...
# ...                                                   ...
# 749852                                        ['express']
# 752893  ['python', 'java', 'scala', 'sql', 'postgresql...
# 765797                                         ['python']
# 767505  ['python', 'azure', 'numpy', 'pandas', 'scikit...
# 771592             ['sql', 'bigquery', 'spark', 'hadoop']
#
#                                           job_type_skills
# 11741   {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 15254   {'analyst_tools': ['word', 'excel', 'powerpoin...
# 29149   {'libraries': ['tensorflow'], 'os': ['linux'],...
# 58901   {'analyst_tools': ['tableau'], 'cloud': ['data...
# 80165   {'libraries': ['spark', 'kafka'], 'other': ['k...
# ...                                                   ...
# 749852                     {'webframeworks': ['express']}
# 752893  {'cloud': ['oracle', 'azure', 'aws'], 'databas...
# 765797                        {'programming': ['python']}
# 767505  {'cloud': ['azure'], 'libraries': ['numpy', 'p...
# 771592  {'cloud': ['bigquery'], 'libraries': ['spark',...
#
# [82 rows x 17 columns]

# %%
gr_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median','min','max','count']).sort_values(by='median', ascending=False)
# Out:
#                              median      min       max  count
# job_title_short
# Machine Learning Engineer  101029.0  72900.0  177283.0     14
# Data Analyst                99500.0  53014.0  200000.0     16
# Data Engineer               96773.0  45000.0  147500.0     24
# Data Scientist              89885.0  51068.0  171121.0     12
# Senior Data Scientist       89187.5  72900.0  200000.0      6
# Software Engineer           81000.0  56700.0  156500.0      6
# Business Analyst            63000.0  63000.0   72900.0      3
# Senior Data Engineer        45000.0  45000.0   45000.0      1
